# %% [markdown]
# # Scraping Football Data from Understat.com
#
# This code is used to scrape football data from various data sources, in this case, it'll be from understat.com

# %% [markdown]
# ## 1. Importing the required packages and modules

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %% [markdown]
# ## 2. Creating the URL

# %%
base_url = 'https://understat.com/match/'
match = str(input('Match ID:'))
url = base_url + match
# Out:
# Match ID:14606

# %% [markdown]
# ## In this example, we'll use the data from Tottenham Hotspur vs Aston Villa on 21st March of 2021

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
#  	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22412050\x22,\x22minute\x22\x3A\x2257\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.889000015258789\x22,\x22Y\x22\x3A\x220.544000015258789\x22,\x22xG\x22\x3A\x220.10845217108726501\x22,\x22player\x22\x3A\x22Tr\x5Cu00e9z\x5Cu00e9guet\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227722\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2214606\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Tottenham\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D03\x2D21\x2019\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Morgan\x20Sanson\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22412051\x22,\x22minute\x22\x3A\x2258\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.7930000305175782\x22,\x22Y\x22\x3A\x220.5879999923706055\x22,\x22xG\x22\x3A\x220.03506242111325264\x22,\x22player\x22\x3A\x22John\x20McGinn\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227723\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2214606\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Tottenham\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D03\x2D21\x2019\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Matt\x20Targett\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22412052\x22,\x22minute\x22\x3A\x2260\x22,\x22result\x22\x3A\x22ShotOnPost\x22,\x22X\x22\x3A\x220.755\x22,\x22Y\x22\x3A\x220.765\x22,\x22xG\x22\x3A\x220.013734503649175167\x22,\x22player\x22\x3A\x22Anwar\x20El\x20Ghazi\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x225612\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2214606\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Tottenham\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D03\x2D21\x2019\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Matt\x20Targett\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22412054\x22,\x22minute\x22\x3A\x2272\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.81\x22,\x22Y\x22\x3A\x220.3659999847412109\x22,\x22xG\x22\x3A\x220.043730102479457855\x22,\x22player\x22\x3A\x22Tr\x5Cu00e9z\x5Cu00e9guet\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x227722\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2214606\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Tottenham\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D03\x2D21\x2019\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22John\x20McGinn\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22412057\x22,\x22minute\x22\x3A\x2283\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.8569999694824219\x22,\x22Y\x22\x3A\x220.4520000076293945\x22,\x22xG\x22\x3A\x220.08297575265169144\x22,\x22player\x22\x3A\x22Ross\x20Barkley\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x22592\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222020\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2214606\x22,\x22h_team\x22\x3A\x22Aston\x20Villa\x22,\x22a_team\x22\x3A\x22Tottenham\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222021\x2D03\x2D21\x2019\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Keinan\x20Davis\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22412058\x22,\x22minute\x22\x3A\x2283\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.8580000305175781\x22,\x22Y\x22\x3A\x220.425\x22,\x22xG\x22\x3A\x220.06148289144039154\x22,\x22player\x22\x3A\x2 ...
#  		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2214606\x22,\x22fid\x22\x3A\x221485341\x22,\x22h\x22\x3A\x2271\x22,\x22a\x22\x3A\x2282\x22,\x22date\x22\x3A\x222021\x2D03\x2D21\x2019\x3A30\x3A00\x22,\x22league_id\x22\x3A\x221\x22,\x22season\x22\x3A\x222020\x22,\x22h_goals\x22\x3A\x220\x22,\x22a_goals\x22\x3A\x222\x22,\x22team_h\x22\x3A\x22Aston\x20Villa\x22,\x22team_a\x22\x3A\x22Tottenham\x22,\x22h_xg\x22\x3A\x220.439681\x22,\x22a_xg\x22\x3A\x221.72011\x22,\x22h_w\x22\x3A\x220.0436\x22,\x22h_d\x22\x3A\x220.1674\x22,\x22h_l\x22\x3A\x220.789\x22,\x22league\x22\x3A\x22EPL\x22,\x22h_shot\x22\x3A\x228\x22,\x22a_shot\x22\x3A\x229\x22,\x22h_shotOnTarget\x22\x3A\x221\x22,\x22a_shotOnTarget\x22\x3A\x223\x22,\x22h_deep\x22\x3A\x228\x22,\x22a_deep\x22\x3A\x226\x22,\x22a_ppda\x22\x3A\x2210.8000\x22,\x22h_ppda\x22\x3A\x226.3421\x22\x7D');
#  </script>,
#  <script>
#  	var rostersData	= JSON.parse('\x7B\x22h\x22\x3A\x7B\x22458941\x22\x3A\x7B\x22id\x22\x3A\x22458941\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x224401\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22GK\x22,\x22player\x22\x3A\x22Emiliano\x20Martinez\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220\x22,\x22xGBuildup\x22\x3A\x220\x22,\x22positionOrder\x22\x3A\x221\x22\x7D,\x22458942\x22\x3A\x7B\x22id\x22\x3A\x22458942\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x228864\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DR\x22,\x22player\x22\x3A\x22Matthew\x20Cash\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x221\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220\x22,\x22xGBuildup\x22\x3A\x220\x22,\x22positionOrder\x22\x3A\x222\x22\x7D,\x22458944\x22\x3A\x7B\x22id\x22\x3A\x22458944\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x221024\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Tyrone\x20Mings\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220\x22,\x22xGBuildup\x22\x3A\x220\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22458943\x22\x3A\x7B\x22id\x22\x3A\x22458943\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x227726\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Ezri\x20Konsa\x20Ngoyo\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.3103383779525757\x22,\x22xGBuildup\x22\x3A\x220.3103383779525757\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22458945\x22\x3A\x7B\x22id\x22\x3A\x22458945\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x22884\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22DL\x22,\x22player\x22\x3A\x22Matt\x20Targett\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x221\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x222\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220.04879692569375038\x22,\x22xGChain\x22\x3A\x220.2069530487060547\x22,\x22xGBuildup\x22\x3A\x220.1581561118364334\x22,\x22positionOrder\x22\x3A\x224\x22\x7D,\x22458947\x22\x3A\x7B\x22id\x22\x3A\x22458947\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2267\x22,\x22player_id\x22\x3A\x223696\x22,\x22team_id\x22\x3A\x2271\x22,\x22position\x22\x3A\x22MC\x22,\x22player\x22\x3A\x22Morgan\x20Sanson\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x22458954\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x221\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3 ...
#  </script>,
#  <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>,
#  <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>,
#  <script>
#  		WebFont.load({
#  			google: {
#  				families: ['Barlow:500', 'Anton']
#  			},
#  			active: function(){
#  				flagFontsLoading = true;
#  			}
#  		});
#  		var BASE_URL = 'https://understat.com/',
#  			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x223542\x22\x7D') ;
#  	</script>,
#  <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>,
#  <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>,
#  <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>,
#  <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>,
#  <script>
#  		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#  		ga('create', 'UA-101482034-1', 'auto');
#  		ga('send', 'pageview');
#
#  					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
#  			</script>,
#  <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>]

# %% [markdown]
# ## 3. From scripts, we'll only take the shots data

# %%
strings = scripts[1].string #since the shots data is in the second element of the scripts list
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22412050\\x22,\\x22minute\\x22\\x3A\\x2257\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.889000015258789\\x22,\\x22Y\\x22\\x3A\\x220.544000015258789\\x22,\\x22xG\\x22\\x3A\\x220.10845217108726501\\x22,\\x22player\\x22\\x3A\\x22Tr\\x5Cu00e9z\\x5Cu00e9guet\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x227722\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2214606\\x22,\\x22h_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22a_team\\x22\\x3A\\x22Tottenham\\x22,\\x22h_goals\\x22\\x3A\\x220\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D03\\x2D21\\x2019\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Morgan\\x20Sanson\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22412051\\x22,\\x22minute\\x22\\x3A\\x2258\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.7930000305175782\\x22,\\x22Y\\x22\\x3A\\x220.5879999923706055\\x22,\\x22xG\\x22\\x3A\\x220.03506242111325264\\x22,\\x22player\\x22\\x3A\\x22John\\x20McGinn\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x227723\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2214606\\x22,\\x22h_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22a_team\\x22\\x3A\\x22Tottenham\\x22,\\x22h_goals\\x22\\x3A\\x220\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D03\\x2D21\\x2019\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Matt\\x20Targett\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22412052\\x22,\\x22minute\\x22\\x3A\\x2260\\x22,\\x22result\\x22\\x3A\\x22ShotOnPost\\x22,\\x22X\\x22\\x3A\\x220.755\\x22,\\x22Y\\x22\\x3A\\x220.765\\x22,\\x22xG\\x22\\x3A\\x220.013734503649175167\\x22,\\x22player\\x22\\x3A\\x22Anwar\\x20El\\x20Ghazi\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x225612\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2214606\\x22,\\x22h_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22a_team\\x22\\x3A\\x22Tottenham\\x22,\\x22h_goals\\x22\\x3A\\x220\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D03\\x2D21\\x2019\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Matt\\x20Targett\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22412054\\x22,\\x22minute\\x22\\x3A\\x2272\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.81\\x22,\\x22Y\\x22\\x3A\\x220.3659999847412109\\x22,\\x22xG\\x22\\x3A\\x220.043730102479457855\\x22,\\x22player\\x22\\x3A\\x22Tr\\x5Cu00e9z\\x5Cu00e9guet\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x227722\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2214606\\x22,\\x22h_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22a_team\\x22\\x3A\\x22Tottenham\\x22,\\x22h_goals\\x22\\x3A\\x220\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222021\\x2D03\\x2D21\\x2019\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22John\\x20McGinn\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22412057\\x22,\\x22minute\\x22\\x3A\\x2283\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.8569999694824219\\x22,\\x22Y\\x22\\x3A\\x220.4520000076293945\\x22,\\x22xG\\x22\\x3A\\x220.08297575265169144\\x22,\\x22player\\x22\\x3A\\x22Ross\\x20Barkley\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22592\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222020\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2214606\ ...

# %%
#as we can see, it's still a little bit dirty so we'll have to strip certain symbol so only JSON data remains

ind_start = strings.index("('")+2
ind_end = strings.index("')")

# %% [markdown]
# ## Next, we'll convert strings into JSON data

# %%
json_data = strings[ind_start:ind_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

data = json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '412050',
#    'minute': '57',
#    'result': 'BlockedShot',
#    'X': '0.889000015258789',
#    'Y': '0.544000015258789',
#    'xG': '0.10845217108726501',
#    'player': 'Trézéguet',
#    'h_a': 'h',
#    'player_id': '7722',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Morgan Sanson',
#    'lastAction': 'Pass'},
#   {'id': '412051',
#    'minute': '58',
#    'result': 'SavedShot',
#    'X': '0.7930000305175782',
#    'Y': '0.5879999923706055',
#    'xG': '0.03506242111325264',
#    'player': 'John McGinn',
#    'h_a': 'h',
#    'player_id': '7723',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Matt Targett',
#    'lastAction': 'Pass'},
#   {'id': '412052',
#    'minute': '60',
#    'result': 'ShotOnPost',
#    'X': '0.755',
#    'Y': '0.765',
#    'xG': '0.013734503649175167',
#    'player': 'Anwar El Ghazi',
#    'h_a': 'h',
#    'player_id': '5612',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Matt Targett',
#    'lastAction': 'Pass'},
#   {'id': '412054',
#    'minute': '72',
#    'result': 'MissedShots',
#    'X': '0.81',
#    'Y': '0.3659999847412109',
#    'xG': '0.043730102479457855',
#    'player': 'Trézéguet',
#    'h_a': 'h',
#    'player_id': '7722',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'John McGinn',
#    'lastAction': 'Pass'},
#   {'id': '412057',
#    'minute': '83',
#    'result': 'BlockedShot',
#    'X': '0.8569999694824219',
#    'Y': '0.4520000076293945',
#    'xG': '0.08297575265169144',
#    'player': 'Ross Barkley',
#    'h_a': 'h',
#    'player_id': '592',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Keinan Davis',
#    'lastAction': 'Pass'},
#   {'id': '412058',
#    'minute': '83',
#    'result': 'BlockedShot',
#    'X': '0.8580000305175781',
#    'Y': '0.425',
#    'xG': '0.06148289144039154',
#    'player': 'Keinan Davis',
#    'h_a': 'h',
#    'player_id': '1053',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Ross Barkley',
#    'lastAction': 'TakeOn'},
#   {'id': '412059',
#    'minute': '83',
#    'result': 'BlockedShot',
#    'X': '0.8180000305175781',
#    'Y': '0.7069999694824218',
#    'xG': '0.019062310457229614',
#    'player': 'Ollie Watkins',
#    'h_a': 'h',
#    'player_id': '8865',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '412060',
#    'minute': '85',
#    'result': 'BlockedShot',
#    'X': '0.8490000152587891',
#    'Y': '0.38',
#    'xG': '0.07518036663532257',
#    'player': 'Ollie Watkins',
#    'h_a': 'h',
#    'player_id': '8865',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'John McGinn',
#    'lastAction': 'Pass'}],
#  'a': [{'id': '412044',
#    'minute': '4',
#    'result': 'BlockedShot',
#    'X': '0.7719999694824219',
#    'Y': '0.32099998474121094',
#    'xG': '0.023315519094467163',
#    'player': 'Harry Kane',
#    'h_a': 'a',
#    'player_id': '647',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Giovani Lo Celso',
#    'lastAction': 'Pass'},
#   {'id': '412045',
#    'minute': '28',
#    'result': 'Goal',
#    'X': '0.9590000152587891',
#    'Y': '0.45799999237060546',
#    'xG': '0.6499724388122559',
#    'player': 'Carlos Vinicius',
#    'h_a': 'a',
#    'player_id': '7395',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Lucas Moura',
#    'lastAction': 'Pass'},
#   {'id': '412046',
#    'minute': '35',
#    'result': 'BlockedShot',
#    'X': '0.85',
#    'Y': '0.48200000762939454',
#    'xG': '0.0706346407532692',
#    'player': 'Carlos Vinicius',
#    'h_a': 'a',
#    'player_id': '7395',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'LeftFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Sergio Reguilón',
#    'lastAction': 'Cross'},
#   {'id': '412047',
#    'minute': '41',
#    'result': 'MissedShots',
#    'X': '0.9390000152587891',
#    'Y': '0.4540000152587891',
#    'xG': '0.057559773325920105',
#    'player': 'Harry Kane',
#    'h_a': 'a',
#    'player_id': '647',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'Head',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Lucas Moura',
#    'lastAction': 'Aerial'},
#   {'id': '412048',
#    'minute': '41',
#    'result': 'MissedShots',
#    'X': '0.745999984741211',
#    'Y': '0.4779999923706055',
#    'xG': '0.013745012693107128',
#    'player': 'Tanguy NDombele Alvaro',
#    'h_a': 'a',
#    'player_id': '5962',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '412049',
#    'minute': '47',
#    'result': 'BlockedShot',
#    'X': '0.784000015258789',
#    'Y': '0.5570000076293945',
#    'xG': '0.04467565938830376',
#    'player': 'Harry Kane',
#    'h_a': 'a',
#    'player_id': '647',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Lucas Moura',
#    'lastAction': 'Pass'},
#   {'id': '412053',
#    'minute': '67',
#    'result': 'Goal',
#    'X': '0.885',
#    'Y': '0.5',
#    'xG': '0.7611688375473022',
#    'player': 'Harry Kane',
#    'h_a': 'a',
#    'player_id': '647',
#    'situation': 'Penalty',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '412055',
#    'minute': '77',
#    'result': 'SavedShot',
#    'X': '0.845999984741211',
#    'Y': '0.4420000076293945',
#    'xG': '0.08070853352546692',
#    'player': 'Pierre-Emile Højbjerg',
#    'h_a': 'a',
#    'player_id': '343',
#    'situation': 'OpenPlay',
#    'season': '2020',
#    'shotType': 'RightFoot',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': None,
#    'lastAction': 'Tackle'},
#   {'id': '412056',
#    'minute': '81',
#    'result': 'MissedShots',
#    'X': '0.9269999694824219',
#    'Y': '0.37099998474121093',
#    'xG': '0.018329372629523277',
#    'player': 'Joe Rodon',
#    'h_a': 'a',
#    'player_id': '6377',
#    'situation': 'FromCorner',
#    'season': '2020',
#    'shotType': 'Head',
#    'match_id': '14606',
#    'h_team': 'Aston Villa',
#    'a_team': 'Tottenham',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2021-03-21 19:30:00',
#    'player_assisted': 'Lucas Moura',
#    'lastAction': 'BallTouch'}]}

# %%
x = []
y = []
xg = []
team = []
time = []
data_away = data['a']
data_home = data['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'xG':
            xg.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'minute':
            time.append(data_home[index][key])
            
for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'xG':
            xg.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'minute':
            time.append(data_away[index][key])

# %% [markdown]
# ## Last, we'll create a DataFrame

# %%
col_names= ['x', 'y','time', 'xg', 'team']
df = pd.DataFrame([x,y,time,xg,team], index=col_names)

# %%
df
# Out:
#                        0                    1                     2   \
# x       0.889000015258789   0.7930000305175782                 0.755
# y       0.544000015258789   0.5879999923706055                 0.765
# time                   57                   58                    60
# xg    0.10845217108726501  0.03506242111325264  0.013734503649175167
# team          Aston Villa          Aston Villa           Aston Villa
#
#                         3                    4                    5   \
# x                     0.81   0.8569999694824219   0.8580000305175781
# y       0.3659999847412109   0.4520000076293945                0.425
# time                    72                   83                   83
# xg    0.043730102479457855  0.08297575265169144  0.06148289144039154
# team           Aston Villa          Aston Villa          Aston Villa
#
#                         6                    7                     8   \
# x       0.8180000305175781   0.8490000152587891    0.7719999694824219
# y       0.7069999694824218                 0.38   0.32099998474121094
# time                    83                   85                     4
# xg    0.019062310457229614  0.07518036663532257  0.023315519094467163
# team           Aston Villa          Aston Villa             Tottenham
#
#                        9                    10                    11  \
# x      0.9590000152587891                 0.85    0.9390000152587891
# y     0.45799999237060546  0.48200000762939454    0.4540000152587891
# time                   28                   35                    41
# xg     0.6499724388122559   0.0706346407532692  0.057559773325920105
# team            Tottenham            Tottenham             Tottenham
#
#                         12                   13                  14  \
# x        0.745999984741211    0.784000015258789               0.885
# y       0.4779999923706055   0.5570000076293945                 0.5
# time                    41                   47                  67
# xg    0.013745012693107128  0.04467565938830376  0.7611688375473022
# team             Tottenham            Tottenham           Tottenham
#
#                        15                    16
# x       0.845999984741211    0.9269999694824219
# y      0.4420000076293945   0.37099998474121093
# time                   77                    81
# xg    0.08070853352546692  0.018329372629523277
# team            Tottenham             Tottenham

# %%
df = df.T
df
# Out:
#                      x                    y time                    xg  \
# 0    0.889000015258789    0.544000015258789   57   0.10845217108726501
# 1   0.7930000305175782   0.5879999923706055   58   0.03506242111325264
# 2                0.755                0.765   60  0.013734503649175167
# 3                 0.81   0.3659999847412109   72  0.043730102479457855
# 4   0.8569999694824219   0.4520000076293945   83   0.08297575265169144
# 5   0.8580000305175781                0.425   83   0.06148289144039154
# 6   0.8180000305175781   0.7069999694824218   83  0.019062310457229614
# 7   0.8490000152587891                 0.38   85   0.07518036663532257
# 8   0.7719999694824219  0.32099998474121094    4  0.023315519094467163
# 9   0.9590000152587891  0.45799999237060546   28    0.6499724388122559
# 10                0.85  0.48200000762939454   35    0.0706346407532692
# 11  0.9390000152587891   0.4540000152587891   41  0.057559773325920105
# 12   0.745999984741211   0.4779999923706055   41  0.013745012693107128
# 13   0.784000015258789   0.5570000076293945   47   0.04467565938830376
# 14               0.885                  0.5   67    0.7611688375473022
# 15   0.845999984741211   0.4420000076293945   77   0.08070853352546692
# 16  0.9269999694824219  0.37099998474121093   81  0.018329372629523277
#
#            team
# 0   Aston Villa
# 1   Aston Villa
# 2   Aston Villa
# 3   Aston Villa
# 4   Aston Villa
# 5   Aston Villa
# 6   Aston Villa
# 7   Aston Villa
# 8     Tottenham
# 9     Tottenham
# 10    Tottenham
# 11    Tottenham
# 12    Tottenham
# 13    Tottenham
# 14    Tottenham
# 15    Tottenham
# 16    Tottenham

# %% [markdown]
# This DataFrame can be exported and I can use it to make an xG timeline or shot maps.

# %%
df.to_csv(r'C:\Users\edgar\Desktop\stuff\tutorial python\Tottenham vs Aston Villa.csv', index = False)

# %% [markdown]
# ## Credits
#
# This is from Mckay Johns' tutorial on <a href="https://www.youtube.com/watch?v=IsR5FrjNmro&ab_channel=McKayJohns">scraping data for football analytics </a>. Check his other works <a href="https://www.youtube.com/channel/UCmqincDKps3syxvD4hbODSg"> here </a>
